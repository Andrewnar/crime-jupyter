# %% [markdown]
# Global GHG Emissions - Data Manipulation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\anarv\Desktop\Agriculture_Emissions_Data.csv")

# %%
'''
#Unfinished code... attempting to create user input into code and have
#the user be able to select certain years/countries to veiw data table.

countryDf = df.groupby(["Area", "Year"])["Value"].sum()

userCountry = str(input("Which country do you wish to view? "))
userYear = int(input("Which year do you wish to view? "))

print(countryDf.loc[userCountry])
print(countryDf.loc[userCountry][userYear])
'''
# Out:
# '\n#Unfinished code... attempting to create user input into code and have\n#the user be able to select certain years/countries to veiw data table.\n\ncountryDf = df.groupby(["Area", "Year"])["Value"].sum()\n\nuserCountry = str(input("Which country do you wish to view? "))\nuserYear = int(input("Which year do you wish to view? "))\n\nprint(countryDf.loc[userCountry])\nprint(countryDf.loc[userCountry][userYear])\n'

# %%
#Plots the annual increase in mean GHG emissions
#Takes mean pollution of all countries and groups it by year.
#Plots avgs into plot function.

pollutionIncreaseByYear = df.loc[:, ['Year Code', 'Value']].groupby('Year Code')
avgs = pollutionIncreaseByYear.mean()
x = avgs.index
y1 = avgs.Value
def plot(x, y, ax, title, y_label):
    ax.set_title(title)
    ax.set_ylabel(y_label)
    ax.plot(x, y)
    ax.margins(x=0, y=0)

fig, ax = plt.subplots()
plot(x, y1, ax, 'Annual increase in mean GHG emissions from 1969 to (Projected) 2050', 'GHG Emissions (Gigagrams)')
